# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('training_log.csv')
df
# Out:
#     epoch      loss       acc
# 0       1  2.661635  0.301959
# 1       2  1.564131  0.534637
# 2       3  1.326819  0.586906
# 3       4  1.216882  0.615645
# 4       5  1.142529  0.636300
# ..    ...       ...       ...
# 95     96  0.364534  0.876015
# 96     97  0.361532  0.877945
# 97     98  0.360079  0.877930
# 98     99  0.358776  0.880146
# 99    100  0.357373  0.880146
#
# [100 rows x 3 columns]

# %%
sns.set()
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'])
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'])
plt.title('Training Accuracy over Epochs')
plt.show()
